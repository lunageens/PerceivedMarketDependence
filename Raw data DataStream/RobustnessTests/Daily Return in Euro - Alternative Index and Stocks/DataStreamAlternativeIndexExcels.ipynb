# %% [markdown]
# This notebook serves the purpose of creating the correct excels to load datastream data regarding alternative indexes.

# %%
import pandas as pd
from openpyxl import Workbook
from openpyxl.utils import get_column_letter
import datetime
from dateutil.relativedelta import relativedelta

# %%
# Parameters
memonic = 'ExampleMemonic'
name = 'ExampleName'
startdate = datetime.date(2002, 1, 1)
enddate = datetime.date(2023, 1, 1)

# %%
# Helper function to find the last weekday before a given date
def get_last_weekday(date):
  date -= datetime.timedelta(days=1) #Get day before
  while date.weekday() > 4:  # 0 = Monday, 1 = Tuesday, ..., 4 = Friday
    date -= datetime.timedelta(days=1)
  return date

# %%
# Calculate startdate minus 1 year, last weekday before that
startdate_minus1y = startdate - datetime.timedelta(days=365)
print(startdate_minus1y)
startdate_minus1y = get_last_weekday(startdate_minus1y)
print(startdate_minus1y)
# Out:
# 2001-01-01
# 2000-12-29

# %%
# Create first Excel file for the Index
wb1 = Workbook()
ws1 = wb1.active
ws1['A1'] = f'"=DSGRID("{memonic}";"X(RI)~E";"{startdate_minus1y}";"{enddate}";"D;"' \
            'RowHeader=true;ColHeader=true;Heading=true;Curn=true;' \
            'DispSeriesDescription=true;YearlyTSFormat=false;QuarterlyTSFormat=false;' \
            'MonthlyTSFormat=False;"")'
wb1.save(f'Index{name}_DailyReturn.xlsx')

# %%
# Create second Excel file for the Stocks
wb2 = Workbook()
ws2 = wb2.active
ws2.title = "RequestTable"

# Columns for the RequestTable
columns = ["Update", "Request Type", "Format", "Series", "Datatype",
           "Start Date", "End Date", "Freq", "Data Destination"]

for idx, column in enumerate(columns, 1):
    ws2[f'{get_column_letter(idx)}1'] = column

# Iterate through quarters
row = 2
for year in range(startdate.year, enddate.year + 1):
    for month in [1, 4, 7, 10]:
        quarter_date = datetime.date(year, month, 1) # eg 2002-01-01
        print("Start of the quarter: " + str(quarter_date))
        #Get end date row
        next_quarter_start = quarter_date + relativedelta(months=3)# eg 2002-04-01
        print("Start of the next quarter: " +  str(next_quarter_start))
        last_day_of_quarter = get_last_weekday(next_quarter_start) # 2002-03-29
        print("Last weekday of the quarter: " + str(last_day_of_quarter))
        # Get start date row
        last_weekday_of_last_year = get_last_weekday(datetime.date(year-1, month, 1))
        print("Last weekday before year prior to quarter: " + str(last_weekday_of_last_year))
        print("----")

        mm_yy = f'{quarter_date.month:02}{str(quarter_date.year)[2:]}'
        ws2[f'A{row}'] = "YES"
        ws2[f'B{row}'] = "TSL"
        ws2[f'C{row}'] = "RCT"
        ws2[f'D{row}'] = f'L{memonic}{mm_yy}'
        ws2[f'E{row}'] = "X(RI)~E"
        ws2[f'F{row}'] = last_weekday_of_last_year
        ws2[f'G{row}'] = last_day_of_quarter
        ws2[f'H{row}'] = "Daily"
        ws2[f'I{row}'] = f"='{mm_yy}'!$A$1"
        ws2b = wb2.create_sheet(title=mm_yy)
        row += 1

wb2.save(f'Stocks{name}_DailyReturn.xlsx')
# Out:
# Start of the quarter: 2002-01-01
# Start of the next quarter: 2002-04-01
# Last weekday of the quarter: 2002-03-29
# Last weekday before year prior to quarter: 2000-12-29
# ----
# Start of the quarter: 2002-04-01
# Start of the next quarter: 2002-07-01
# Last weekday of the quarter: 2002-06-28
# Last weekday before year prior to quarter: 2001-03-30
# ----
# Start of the quarter: 2002-07-01
# Start of the next quarter: 2002-10-01
# Last weekday of the quarter: 2002-09-30
# Last weekday before year prior to quarter: 2001-06-29
# ----
# Start of the quarter: 2002-10-01
# Start of the next quarter: 2003-01-01
# Last weekday of the quarter: 2002-12-31
# Last weekday before year prior to quarter: 2001-09-28
# ----
# Start of the quarter: 2003-01-01
# Start of the next quarter: 2003-04-01
# Last weekday of the quarter: 2003-03-31
# Last weekday before year prior to quarter: 2001-12-31
# ----
# Start of the quarter: 2003-04-01
# Start of the next quarter: 2003-07-01
# Last weekday of the quarter: 2003-06-30
# Last weekday before year prior to quarter: 2002-03-29
# ----
# Start of the quarter: 2003-07-01
# Start of the next quarter: 2003-10-01
# Last weekday of the quarter: 2003-09-30
# Last weekday before year prior to quarter: 2002-06-28
# ----
# Start of the quarter: 2003-10-01
# Start of the next quarter: 2004-01-01
# Last weekday of the quarter: 2003-12-31
# Last weekday before year prior to quarter: 2002-09-30
# ----
# Start of the quarter: 2004-01-01
# Start of the next quarter: 2004-04-01
# Last weekday of the quarter: 2004-03-31
# Last weekday before year prior to quarter: 2002-12-31
# ----
# Start of the quarter: 2004-04-01
# Start of the next quarter: 2004-07-01
# Last weekday of the quarter: 2004-06-30
# Last weekday before year prior to quarter: 2003-03-31
# ----
# Start of the quarter: 2004-07-01
# Start of the next quarter: 2004-10-01
# Last weekday of the quarter: 2004-09-30
# Last weekday before year prior to quarter: 2003-06-30
# ----
# Start of the quarter: 2004-10-01
# Start of the next quarter: 2005-01-01
# Last weekday of the quarter: 2004-12-31
# Last weekday before year prior to quarter: 2003-09-30
# ----
# Start of the quarter: 2005-01-01
# Start of the next quarter: 2005-04-01
# Last weekday of the quarter: 2005-03-31
# Last weekday before year prior to quarter: 2003-12-31
# ----
# Start of the quarter: 2005-04-01
# Start of the next quarter: 2005-07-01
# Last weekday of the quarter: 2005-06-30
# Last weekday before year prior to quarter: 2004-03-31
# ----
# Start of the quarter: 2005-07-01
# Start of the next quarter: 2005-10-01
# Last weekday of the quarter: 2005-09-30
# Last weekday before year prior to quarter: 2004-06-30
# ----
# Start of the quarter: 2005-10-01
# Start of the next quarter: 2006-01-01
# Last weekday of the quarter: 2005-12-30
# Last weekday before year prior to quarter: 2004-09-30
# ----
# Start of the quarter: 2006-01-01
# Start of the next quarter: 2006-04-01
# Last weekday of the quarter: 2006-03-31
# Last weekday before year prior to quarter: 2004-12-31
# ----
# Start of the quarter: 2006-04-01
# Start of the next quarter: 2006-07-01
# Last weekday of the quarter: 2006-06-30
# Last weekday before year prior to quarter: 2005-03-31
# ----
# Start of the quarter: 2006-07-01
# Start of the next quarter: 2006-10-01
# Last weekday of the quarter: 2006-09-29
# Last weekday before year prior to quarter: 2005-06-30
# ----
# Start of the quarter: 2006-10-01
# Start of the next quarter: 2007-01-01
# Last weekday of the quarter: 2006-12-29
# Last weekday before year prior to quarter: 2005-09-30
# ----
# Start of the quarter: 2007-01-01
# Start of the next quarter: 2007-04-01
# Last weekday of the quarter: 2007-03-30
# Last weekday before year prior to quarter: 2005-12-30
# ----
# Start of the quarter: 2007-04-01
# Start of the next quarter: 2007-07-01
# Last weekday of the quarter: 2007-06-29
# Last weekday before year prior to quarter: 2006-03-31
# ----
# Start of the quarter: 2007-07-01
# Start of the next quarter: 2007-10-01
# Last weekday of the quarter: 2007-09-28
# Last weekday before year prior to quarter: 2006-06-30
# ----
# Start of the quarter: 2007-10-01
# Start of the next quarter: 2008-01-01
# Last weekday of the quarter: 2007-12-31
# Last weekday before year prior to quarter: 2006-09-29
# ----
# Start of the quarter: 2008-01-01
# Start of the next quarter: 2008-04-01
# Last weekday of the quarter: 2008-03-31
# Last weekday before year prior to quarter: 2006-12-29
# ----
# Start of the quarter: 2008-04-01
# Start of the next quarter: 2008-07-01
# Last weekday of the quarter: 2008-06-30
# Last weekday before year prior to quarter: 2007-03-30
# ----
# Start of the quarter: 2008-07-01
# Start of the next quarter: 2008-10-01
# Last weekday of the quarter: 2008-09-30
# Last weekday before year prior to quarter: 2007-06-29
# ----
# Start of the quarter: 2008-10-01
# Start of the next quarter: 2009-01-01
# Last weekday of the quarter: 2008-12-31
# Last weekday before year prior to quarter: 2007-09-28
# ----
# Start of the quarter: 2009-01-01
# Start of the next quarter: 2009-04-01
# Last weekday of the quarter: 2009-03-31
# Last weekday before year prior to quarter: 2007-12-31
# ----
# Start of the quarter: 2009-04-01
# Start of the next quarter: 2009-07-01
# Last weekday of the quarter: 2009-06-30
# Last weekday before year prior to quarter: 2008-03-31
# ----
# Start of the quarter: 2009-07-01
# Start of the next quarter: 2009-10-01
# Last weekday of the quarter: 2009-09-30
# Last weekday before year prior to quarter: 2008-06-30
# ----
# Start of the quarter: 2009-10-01
# Start of the next quarter: 2010-01-01
# Last weekday of the quarter: 2009-12-31
# Last weekday before year prior to quarter: 2008-09-30
# ----
# Start of the quarter: 2010-01-01
# Start of the next quarter: 2010-04-01
# Last weekday of the quarter: 2010-03-31
# Last weekday before year prior to quarter: 2008-12-31
# ----
# Start of the quarter: 2010-04-01
# Start of the next quarter: 2010-07-01
# Last weekday of the quarter: 2010-06-30
# Last weekday before year prior to quarter: 2009-03-31
# ----
# Start of the quarter: 2010-07-01
# Start of the next quarter: 2010-10-01
# Last weekday of the quarter: 2010-09-30
# Last weekday before year prior to quarter: 2009-06-30
# ----
# Start of the quarter: 2010-10-01
# Start of the next quarter: 2011-01-01
# Last weekday of the quarter: 2010-12-31
# Last weekday before year prior to quarter: 2009-09-30
# ----
# Start of the quarter: 2011-01-01
# Start of the next quarter: 2011-04-01
# Last weekday of the quarter: 2011-03-31
# Last weekday before year prior to quarter: 2009-12-31
# ----
# Start of the quarter: 2011-04-01
# Start of the next quarter: 2011-07-01
# Last weekday of the quarter: 2011-06-30
# Last weekday before year prior to quarter: 2010-03-31
# ----
# Start of the quarter: 2011-07-01
# Start of the next quarter: 2011-10-01
# Last weekday of the quarter: 2011-09-30
# Last weekday before year prior to quarter: 2010-06-30
# ----
# Start of the quarter: 2011-10-01
# Start of the next quarter: 2012-01-01
# Last weekday of the quarter: 2011-12-30
# Last weekday before year prior to quarter: 2010-09-30
# ----
# Start of the quarter: 2012-01-01
# Start of the next quarter: 2012-04-01
# Last weekday of the quarter: 2012-03-30
# Last weekday before year prior to quarter: 2010-12-31
# ----
# Start of the quarter: 2012-04-01
# Start of the next quarter: 2012-07-01
# Last weekday of the quarter: 2012-06-29
# Last weekday before year prior to quarter: 2011-03-31
# ----
# Start of the quarter: 2012-07-01
# Start of the next quarter: 2012-10-01
# Last weekday of the quarter: 2012-09-28
# Last weekday before year prior to quarter: 2011-06-30
# ----
# Start of the quarter: 2012-10-01
# Start of the next quarter: 2013-01-01
# Last weekday of the quarter: 2012-12-31
# Last weekday before year prior to quarter: 2011-09-30
# ----
# Start of the quarter: 2013-01-01
# Start of the next quarter: 2013-04-01
# Last weekday of the quarter: 2013-03-29
# Last weekday before year prior to quarter: 2011-12-30
# ----
# Start of the quarter: 2013-04-01
# Start of the next quarter: 2013-07-01
# Last weekday of the quarter: 2013-06-28
# Last weekday before year prior to quarter: 2012-03-30
# ----
# Start of the quarter: 2013-07-01
# Start of the next quarter: 2013-10-01
# Last weekday of the quarter: 2013-09-30
# Last weekday before year prior to quarter: 2012-06-29
# ----
# Start of the quarter: 2013-10-01
# Start of the next quarter: 2014-01-01
# Last weekday of the quarter: 2013-12-31
# Last weekday before year prior to quarter: 2012-09-28
# ----
# Start of the quarter: 2014-01-01
# Start of the next quarter: 2014-04-01
# Last weekday of the quarter: 2014-03-31
# Last weekday before year prior to quarter: 2012-12-31
# ----
# Start of the quarter: 2014-04-01
# Start of the next quarter: 2014-07-01
# Last weekday of the quarter: 2014-06-30
# Last weekday before year prior to quarter: 2013-03-29
# ----
# Start of the quarter: 2014-07-01
# Start of the next quarter: 2014-10-01
# Last weekday of the quarter: 2014-09-30
# Last weekday before year prior to quarter: 2013-06-28
# ----
# Start of the quarter: 2014-10-01
# Start of the next quarter: 2015-01-01
# Last weekday of the quarter: 2014-12-31
# Last weekday before year prior to quarter: 2013-09-30
# ----
# Start of the quarter: 2015-01-01
# Start of the next quarter: 2015-04-01
# Last weekday of the quarter: 2015-03-31
# Last weekday before year prior to quarter: 2013-12-31
# ----
# Start of the quarter: 2015-04-01
# Start of the next quarter: 2015-07-01
# Last weekday of the quarter: 2015-06-30
# Last weekday before year prior to quarter: 2014-03-31
# ----
# Start of the quarter: 2015-07-01
# Start of the next quarter: 2015-10-01
# Last weekday of the quarter: 2015-09-30
# Last weekday before year prior to quarter: 2014-06-30
# ----
# Start of the quarter: 2015-10-01
# Start of the next quarter: 2016-01-01
# Last weekday of the quarter: 2015-12-31
# Last weekday before year prior to quarter: 2014-09-30
# ----
# Start of the quarter: 2016-01-01
# Start of the next quarter: 2016-04-01
# Last weekday of the quarter: 2016-03-31
# Last weekday before year prior to quarter: 2014-12-31
# ----
# Start of the quarter: 2016-04-01
# Start of the next quarter: 2016-07-01
# Last weekday of the quarter: 2016-06-30
# Last weekday before year prior to quarter: 2015-03-31
# ----
# Start of the quarter: 2016-07-01
# Start of the next quarter: 2016-10-01
# Last weekday of the quarter: 2016-09-30
# Last weekday before year prior to quarter: 2015-06-30
# ----
# Start of the quarter: 2016-10-01
# Start of the next quarter: 2017-01-01
# Last weekday of the quarter: 2016-12-30
# Last weekday before year prior to quarter: 2015-09-30
# ----
# Start of the quarter: 2017-01-01
# Start of the next quarter: 2017-04-01
# Last weekday of the quarter: 2017-03-31
# Last weekday before year prior to quarter: 2015-12-31
# ----
# Start of the quarter: 2017-04-01
# Start of the next quarter: 2017-07-01
# Last weekday of the quarter: 2017-06-30
# Last weekday before year prior to quarter: 2016-03-31
# ----
# Start of the quarter: 2017-07-01
# Start of the next quarter: 2017-10-01
# Last weekday of the quarter: 2017-09-29
# Last weekday before year prior to quarter: 2016-06-30
# ----
# Start of the quarter: 2017-10-01
# Start of the next quarter: 2018-01-01
# Last weekday of the quarter: 2017-12-29
# Last weekday before year prior to quarter: 2016-09-30
# ----
# Start of the quarter: 2018-01-01
# Start of the next quarter: 2018-04-01
# Last weekday of the quarter: 2018-03-30
# Last weekday before year prior to quarter: 2016-12-30
# ----
# Start of the quarter: 2018-04-01
# Start of the next quarter: 2018-07-01
# Last weekday of the quarter: 2018-06-29
# Last weekday before year prior to quarter: 2017-03-31
# ----
# Start of the quarter: 2018-07-01
# Start of the next quarter: 2018-10-01
# Last weekday of the quarter: 2018-09-28
# Last weekday before year prior to quarter: 2017-06-30
# ----
# Start of the quarter: 2018-10-01
# Start of the next quarter: 2019-01-01
# Last weekday of the quarter: 2018-12-31
# Last weekday before year prior to quarter: 2017-09-29
# ----
# Start of the quarter: 2019-01-01
# Start of the next quarter: 2019-04-01
# Last weekday of the quarter: 2019-03-29
# Last weekday before year prior to quarter: 2017-12-29
# ----
# Start of the quarter: 2019-04-01
# Start of the next quarter: 2019-07-01
# Last weekday of the quarter: 2019-06-28
# Last weekday before year prior to quarter: 2018-03-30
# ----
# Start of the quarter: 2019-07-01
# Start of the next quarter: 2019-10-01
# Last weekday of the quarter: 2019-09-30
# Last weekday before year prior to quarter: 2018-06-29
# ----
# Start of the quarter: 2019-10-01
# Start of the next quarter: 2020-01-01
# Last weekday of the quarter: 2019-12-31
# Last weekday before year prior to quarter: 2018-09-28
# ----
# Start of the quarter: 2020-01-01
# Start of the next quarter: 2020-04-01
# Last weekday of the quarter: 2020-03-31
# Last weekday before year prior to quarter: 2018-12-31
# ----
# Start of the quarter: 2020-04-01
# Start of the next quarter: 2020-07-01
# Last weekday of the quarter: 2020-06-30
# Last weekday before year prior to quarter: 2019-03-29
# ----
# Start of the quarter: 2020-07-01
# Start of the next quarter: 2020-10-01
# Last weekday of the quarter: 2020-09-30
# Last weekday before year prior to quarter: 2019-06-28
# ----
# Start of the quarter: 2020-10-01
# Start of the next quarter: 2021-01-01
# Last weekday of the quarter: 2020-12-31
# Last weekday before year prior to quarter: 2019-09-30
# ----
# Start of the quarter: 2021-01-01
# Start of the next quarter: 2021-04-01
# Last weekday of the quarter: 2021-03-31
# Last weekday before year prior to quarter: 2019-12-31
# ----
# Start of the quarter: 2021-04-01
# Start of the next quarter: 2021-07-01
# Last weekday of the quarter: 2021-06-30
# Last weekday before year prior to quarter: 2020-03-31
# ----
# Start of the quarter: 2021-07-01
# Start of the next quarter: 2021-10-01
# Last weekday of the quarter: 2021-09-30
# Last weekday before year prior to quarter: 2020-06-30
# ----
# Start of the quarter: 2021-10-01
# Start of the next quarter: 2022-01-01
# Last weekday of the quarter: 2021-12-31
# Last weekday before year prior to quarter: 2020-09-30
# ----
# Start of the quarter: 2022-01-01
# Start of the next quarter: 2022-04-01
# Last weekday of the quarter: 2022-03-31
# Last weekday before year prior to quarter: 2020-12-31
# ----
# Start of the quarter: 2022-04-01
# Start of the next quarter: 2022-07-01
# Last weekday of the quarter: 2022-06-30
# Last weekday before year prior to quarter: 2021-03-31
# ----
# Start of the quarter: 2022-07-01
# Start of the next quarter: 2022-10-01
# Last weekday of the quarter: 2022-09-30
# Last weekday before year prior to quarter: 2021-06-30
# ----
# Start of the quarter: 2022-10-01
# Start of the next quarter: 2023-01-01
# Last weekday of the quarter: 2022-12-30
# Last weekday before year prior to quarter: 2021-09-30
# ----
# Start of the quarter: 2023-01-01
# Start of the next quarter: 2023-04-01
# Last weekday of the quarter: 2023-03-31
# Last weekday before year prior to quarter: 2021-12-31
# ----
# Start of the quarter: 2023-04-01
# Start of the next quarter: 2023-07-01
# Last weekday of the quarter: 2023-06-30
# Last weekday before year prior to quarter: 2022-03-31
# ----
# Start of the quarter: 2023-07-01
# Start of the next quarter: 2023-10-01
# Last weekday of the quarter: 2023-09-29
# Last weekday before year prior to quarter: 2022-06-30
# ----
# Start of the quarter: 2023-10-01
# Start of the next quarter: 2024-01-01
# Last weekday of the quarter: 2023-12-29
# Last weekday before year prior to quarter: 2022-09-30
# ----
